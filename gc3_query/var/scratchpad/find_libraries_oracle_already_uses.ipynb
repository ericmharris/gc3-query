# %%
import re, os
from pathlib import Path, WindowsPath
from typing import List, Optional, Any, Callable, Dict, Tuple, Union, Set, Generator
from dataclasses import dataclass

BASE_DIR: Path = Path().resolve().parent.parent.parent.parent.joinpath('oracle')


print(f"BASE_DIR={BASE_DIR}")
# Out:
# BASE_DIR=C:\Users\eharris\devel\oracle

# %%
@dataclass
class ImportedLibrary:
    file_path: Path
    library_name: str

# %%
@dataclass
class WalkPath:
    file_path: str
    directories: List[str]
    files: List[str]
        
    def __post_init__(self):
        self.file_path = Path(self.file_path)
        is_dir: bool = self.file_path.is_dir()
        is_file: bool = self.file_path.is_file()
        self.directories = [self.file_path.joinpath(d) for d in self.directories if d not in ['.git']]
        self.files = [self.file_path.joinpath(f) for f in self.files if f.endswith('.py')]

# %%
il01 = ImportedLibrary(r'C:\Users\eharris\devel\oracle\psmcli\setup.py', 'setuptools')
il02 = ImportedLibrary(r'C:\Users\eharris\devel\oracle\psmcli\setup.py', 'setuptools')
are_eq = il01==il02
print(f"il01={il01}, il02={il02}, il01==il02: {are_eq}")
library_name = il01.library_name
is_valid = library_name.isidentifier()
bad_name = '1asdf'
print(f"il01.library_name={il01.library_name}, is a valid python lib name:  {is_valid}")
print(f"bad_name={bad_name}, is a valid python lib name:  {bad_name.isidentifier()}")
# Out:
# il01=ImportedLibrary(file_path='C:\\Users\\eharris\\devel\\oracle\\psmcli\\setup.py', library_name='setuptools'), il02=ImportedLibrary(file_path='C:\\Users\\eharris\\devel\\oracle\\psmcli\\setup.py', library_name='setuptools'), il01==il02: True
# il01.library_name=setuptools, is a valid python lib name:  True
# bad_name=1asdf, is a valid python lib name:  False

# %%
def is_library_name_valid(library_name: str) -> bool:
    return library_name.isidentifier()

print(f"il01.library_name={il01.library_name}, is a valid python lib name:  {is_library_name_valid(il01.library_name)}")
print(f"bad_name={bad_name}, is a valid python lib name:  {is_library_name_valid(bad_name)}")
# Out:
# il01.library_name=setuptools, is a valid python lib name:  True
# bad_name=1asdf, is a valid python lib name:  False

# %%
# walk_base_dir = BASE_DIR.joinpath('psmcli').iterdir()
# psmcli_dir_walk = list(os.walk(BASE_DIR.joinpath('psmcli')))
# base_dir_walk_path = [WalkPath(*w) for w in base_dir_walk]
# psmcli_dir = BASE_DIR.joinpath('psmcli')
# psmcli_dir_glob = psmcli_dir.rglob('*.py')
# type(psmcli_dir_glob)
# for i in psmcli_dir_glob:
#     print(i)

# %%
for i in BASE_DIR.joinpath('psmcli').rglob('*.py'):
    print(i)
# Out:
# C:\Users\eharris\devel\oracle\psmcli\setup.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\argumenttypes.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\configure.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\customexecutor.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\exceptions.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\executor.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\formatter.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\handlers.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\helpformatter.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\messages.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\opccli.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\opcservice.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\utils.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\__init__.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\internal\common_util.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\internal\opc_cloud_storage_handler.py
# C:\Users\eharris\devel\oracle\psmcli\opaascli\internal\__init__.py

# %%
def is_import_line(line: str) -> bool:
    if line.startswith('import'):
        return True
    if line.startswith('from'):
        return True
    return False

# %%
# def walk_base_dir():
#     for 
#     return [WalkPath(*w) for w in os.walk(BASE_DIR)]

# %%
# for k,v in enumerate(base_dir_walk_path):
#     print(f"{k}\t{v}")

# %%
# wbd = walk_base_dir()
# for k,v in enumerate(wbd[:20]):
#     print(f"{k}\t{v}")

# %%
header = """

import datetime
import keyword, os, sys
import re, pathlib


from collections.abc import MutableMapping
from iniparser.lib import *
from iniparser.lib.config import CONFIG
from iniparser.lib.exceptions import IniParserRuntimeError, IniParserSyntaxError, IPCacheUnresovableHostnameError, InvalidFQDNError
"""


# Split jinja_var into a list of valid Python variable/function names (alphanumeric + _)
PYTHON_IDENTIFIER_RE = re.compile(r"""
                                \s*                             # zero or more spaces
                               (?P<identifier>[_A-Za-z]         # first char is alpha or _
                               [_a-zA-Z0-9]*)                   # zero or more alpha-num or _
                               \s*                              # zero or more spaces
                            """, re.VERBOSE)

# %%
# from asdf import ASDF
s = r'from iniparser.lib import *'
# Split jinja_var into a list of valid Python variable/function names (alphanumeric + _)
FROM_IMPORT_RE = re.compile(r"""
                                ^                             # line start
                                \s*                             # zero or more spaces
                                from                             # from
                                \s+                             # one or more spaces
                               (?P<library_name>[_A-Za-z]         # first char is alpha or _
                               [_a-zA-Z0-9]*)                   # zero or more alpha-num or _
                               \s*                              # zero or more spaces
                            """, re.VERBOSE)

# %%
FROM_IMPORT_RE.findall(s)
# Out:
# ['iniparser']

# %%
for line in header.splitlines():
    if FROM_IMPORT_RE.match(line):
        print(FROM_IMPORT_RE.findall(line))
# Out:
# ['collections']
# ['iniparser']
# ['iniparser']
# ['iniparser']

# %%
# Split jinja_var into a list of valid Python variable/function names (alphanumeric + _)
IMPORT_RE = re.compile(r"""
                                ^                             # line start
                                \s*                             # zero or more spaces
                                import                             # from
                                \s+                             # one or more spaces
                               (?P<library_name>[_A-Za-z]         # first char is alpha or _
                               [_a-zA-Z0-9]*)                   # zero or more alpha-num or _
                               \s*                              # zero or more spaces
                            """, re.VERBOSE)

# %%
# s = r'import json'
# IMPORT_RE.findall(s)
# s = r'    import pathlib'
# IMPORT_RE.findall(s)

s = 'import json'
print(f"'{s}' matches IMPORT_RE: {bool(IMPORT_RE.match(s))}")
s = '    import json'
print(f"'{s}' matches IMPORT_RE: {bool(IMPORT_RE.match(s))}")
# Out:
# 'import json' matches IMPORT_RE: True
# '    import json' matches IMPORT_RE: True

# %%
MULTI_IMPORT_RE = re.compile(r"""
                                ^                             # line start
                                \s*                             # zero or more spaces
                                import                             # from
                                \s+                             # one or more spaces
                               (?P<library_name>[_A-Za-z]         # first char is alpha or _
                               [_a-zA-Z0-9]*)                   # zero or more alpha-num or _
                               \s*                              # zero or more spaces
                               ,                              # comma
                            """, re.VERBOSE)

# %%
s = r'import json, os, sys'
if MULTI_IMPORT_RE.match(s):
    import_part, *other_libraries = s.split(',')
    other_libraries = [s.strip() for s in other_libraries]
    print(f'import_part={import_part}, other_libraries={other_libraries}')

    
    
def parse_import_libraries(line: str) -> List[str]:
    """find libraries in 'import os, sys, json' or 'import os' """
    if MULTI_IMPORT_RE.match(line):
        import_part, *other_libraries = s.split(',')
        other_libraries = [s.strip() for s in other_libraries]
        other_libraries.append(import_part.split()[1])
        imported_libraries = [l for l in other_libraries if is_library_name_valid(l)]
        return imported_libraries
    if IMPORT_RE.match(line):
        imported_libraries = [l for l in IMPORT_RE.findall(line) if is_library_name_valid(l)]
        return imported_libraries
    if FROM_IMPORT_RE.match(line):
        imported_libraries = [l for l in FROM_IMPORT_RE.findall(line) if is_library_name_valid(l)]
        return imported_libraries
# Out:
# import_part=import json, other_libraries=['os', 'sys']

# %%
s = r'import json, os, sys'
print(f"'{s}' parsed: {parse_import_libraries(s)}")
s = r'import json'
print(f"'{s}' parsed: {parse_import_libraries(s)}")
s = r'from bravado import http_client'
print(f"'{s}' parsed: {parse_import_libraries(s)}")
# Out:
# 'import json, os, sys' parsed: ['os', 'sys', 'json']
# 'import json' parsed: ['json']
# 'from bravado import http_client' parsed: ['bravado']

# %%
def is_import_line(line: str) -> bool:
    if IMPORT_RE.match(line):
        return True
    if FROM_IMPORT_RE.match(line):
        return True
    if MULTI_IMPORT_RE.match(line):
        return True
    return False

s = '    from exceptions import UnknownArgumentError'
print(f"'{s}' is_import_line: {is_import_line(s)}")
s = '    from helpformatter import OPCHelpCommand, OPCCustomHelpFormatter'
print(f"'{s}' is_import_line: {is_import_line(s)}")
s = '    import exceptions, os, json'
print(f"'{s}' is_import_line: {is_import_line(s)}")
# Out:
# '    from exceptions import UnknownArgumentError' is_import_line: True
# '    from helpformatter import OPCHelpCommand, OPCCustomHelpFormatter' is_import_line: True
# '    import exceptions, os, json' is_import_line: True

# %%
py_file = BASE_DIR.joinpath('psmcli/setup.py')
print(f'py_file={py_file}, exists: {py_file.exists()}')

for line_num, line in enumerate(py_file.read_text().splitlines()):
    if is_import_line(line):
        print(f"{line_num}: {line}")
# Out:
# py_file=C:\Users\eharris\devel\oracle\psmcli\setup.py, exists: True
# 6: import os
# 7: from setuptools import setup, find_packages
# 8: import opaascli

# %%
py_file = BASE_DIR.joinpath('psmcli/opaascli/cliparser.py')
print(f'py_file={py_file}, exists: {py_file.exists()}')

for line_num, line in enumerate(py_file.read_text().splitlines()):
    if is_import_line(line):
        print(f"{line_num}: {line}")
# Out:
# py_file=C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py, exists: True
# 3: import argparse
# 4: import json
# 5: import logging
# 6: import collections as _collections
# 7: import copy as _copy
# 8: import os as _os
# 9: import re as _re
# 10: import sys as _sys
# 11: import textwrap as _textwrap
# 12: from collections import OrderedDict
# 13: from argparse import ArgumentError
# 14: from argparse import _UNRECOGNIZED_ARGS_ATTR, SUPPRESS
# 15: from argparse import _get_action_name
# 16: from gettext import gettext as _, ngettext
# 18:     from argumenttypes import OPCArgument
# 19:     from __init__ import __version__
# 20:     from helpformatter import OPCHelpCommand, OPCCustomHelpFormatter
# 21:     from configure import SetupParser
# 22:     from handlers import RequestParamHandler,AdditionalResponseValues
# 23:     from executor import RequestExecutor
# 24:     from exceptions import UnknownArgumentError
# 25:     from utils import Utils
# 26:     from messages import Messages, ErrorMessages, LocalizationConstants
# 27:     from customexecutor import CUSTOM_IMPL_MAP

# %%
py_file = BASE_DIR.joinpath('psmcli/opaascli/formatter.py')
print(f'py_file={py_file}, exists: {py_file.exists()}')

for line_num, line in enumerate(py_file.read_text().splitlines()):
    if is_import_line(line):
        print(f"{line_num}: {line}")
# Out:
# py_file=C:\Users\eharris\devel\oracle\psmcli\opaascli\formatter.py, exists: True
# 3: import os
# 4: import sys
# 5: import json
# 6: import logging
# 7: import textwrap
# 8: from collections import OrderedDict
# 10:     from utils import Utils, FormatText
# 11:     from messages import ErrorMessages, CatalogConstants
# 48:         import yaml
# 954:             import shutil
# 971:                 import struct
# 972:                 from fcntl import ioctl
# 973:                 from termios import TIOCGWINSZ

# %%
py_file.read_text()
# Out:
# '# Copyright (c) 2015 Oracle and/or its affiliates. All rights reserved.\n# created by sahit.gollapudi\n\nimport os\nimport sys\nimport json\nimport logging \nimport textwrap\nfrom collections import OrderedDict\ntry:\n    from utils import Utils, FormatText\n    from messages import ErrorMessages, CatalogConstants\nexcept:\n    from .utils import Utils, FormatText\n    from .messages import ErrorMessages, CatalogConstants\n\n#======= CONSTANTS ==============================================================\nNUM_PROP_LIST = 5\n#======= CLASSES =================================================================\n\n\nclass OutputFormatter(object):\n    """\n       a generic formatter which needs to implemented in order to get the \n       desired output format specified in the conf file.\n    """\n    def __init__(self, content=None, \\\n                 cmd_dict=None, \\\n                 cmd_name=None, \\\n                 response_headers=None):\n        self._cmd_dict = cmd_dict \n        self._content = content\n        self._cmd_name = cmd_name\n        self._response_headers = response_headers\n        self._max_props = NUM_PROP_LIST\n        self._utils = Utils()\n    \n    @property\n    def content(self):\n        return self._content\n    \n    def _format_content(self):\n        raise NotImplementedError("Not Implemented")\n    \n    def _format_error_content(self):\n        raise NotImplementedError("Not Implemented")\n\n    def _parse_yaml_output(self, output_data):\n        import yaml\n        try:\n            # if the response output is of type str and json compatible,\n            # a json dict obj is returned, otherwise a string,\n            # object is returned.\n            output_data = yaml.load(output_data)\n        except yaml.YAMLError as exc:\n            logger.error("Error while parsing the input as yaml: %s", exc)\n        except Exception as ex:\n            logger.error("Response data is not an Yaml file: %s", ex)\n\n        return output_data\n\nclass JSONFormatter(OutputFormatter):\n    \n    def _format_content(self):\n        data = self.content\n        # BUG FIX: 25350442, Convert YAML response output to json\n        if not isinstance(data, (dict,list)):\n            data = self._parse_yaml_output(data)\n        # commented the sort keys. To maintain the order from the REST response\n        json_formatted = json.dumps(data, indent=4, separators=(\',\',\':\')) #,sort_keys=True)\n        return json_formatted\n    \n    def _format_error_content(self):\n        data = self.content\n        json_formatted = json.dumps(data, indent=4, separators=(\',\',\':\'))\n        return json_formatted\n        \nclass TextFormatter(OutputFormatter):\n    \n    def _format_content(self):\n        # to replace any string if it has \\r\\n for linux\n        data = self.content.replace(\'\\r\',\'\') if self._utils.isLinux() else self.content\n        return data \n\nclass ConciseOutputFormatter(OutputFormatter):\n        \n    def _format_content(self):\n        offset_data = self.content\n        if CatalogConstants.OUTPUT_FILTER in self._cmd_dict and \\\n                        any(param in self._cmd_dict[CatalogConstants.OUTPUT_FILTER] for param in \n                            [CatalogConstants.INCLUDE_PROPERTIES, \\\n                            CatalogConstants.OFFSET]):\n            try:\n                output = None\n                offset = False\n                show_table = False\n                property_list = None\n                # if offset is given and the resulting value json for\n                # the offset is a dict where the include properties are\n                # present in the first level of the JSON - Typically for POST \n                parse_offset_first_level = False\n                show_properties_dynamically = False\n                # Read offset data for additional processing\n                if CatalogConstants.OFFSET in self._cmd_dict[CatalogConstants.OUTPUT_FILTER]:\n      ...

# %%
@dataclass
class ImportedLibrary:
    file_path: Path
    library_name: str

# %%
all_imported_libs: Dict[Path, List[ImportedLibrary]] = {}

# for py_file in BASE_DIR.joinpath('psmcli').rglob('*.py'):
for py_file in BASE_DIR.rglob('*.py'):
    lib_names_in_file = []
    try:
        lines = py_file.read_text().splitlines()
    except UnicodeDecodeError as e:
        print(f"UnicodeDecodeError reading {py_file}:\n{e}")
        
    for line in lines:
        if is_import_line(line):
            try:
                lib_names = parse_import_libraries(line)
                lib_names_in_file.extend(lib_names)
            except TypeError as e:
                print(f"TypeError importing {py_file}:\n{e}")
                
                
    all_imported_libs[py_file] = [ImportedLibrary(file_path=py_file, library_name=name) for name in lib_names_in_file]
    print(f"Found {len(lib_names_in_file)}/{len(all_imported_libs)} imports in {py_file}")
# Out:
# Found 33/1 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\commerce_setup.py
# Found 5/2 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\responseFiles\wls-12.1.2\createMachine.py
# Found 4/3 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\responseFiles\wls-12.1.2\createManagedServer.py
# Found 2/4 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\responseFiles\wls-12.1.2\create_datasources.py
# Found 4/5 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\responseFiles\wls-12.1.2\setJTA.py
# Found 33/6 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.2\commerce_setup.py
# Found 5/7 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.2\responseFiles\wls-12.1.3\createMachine.py
# Found 4/8 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.2\responseFiles\wls-12.1.3\createManagedServer.py
# Found 2/9 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.2\responseFiles\wls-12.1.3\create_datasources.py
# Found 4/10 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.2\responseFiles\wls-12.1.3\setJTA.py
# Found 34/11 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.3\commerce_setup.py
# Found 5/12 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.3\responseFiles\wls-12.2.1\createMachine.py
# Found 4/13 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.3\responseFiles\wls-12.2.1\createManagedServer.py
# Found 2/14 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.3\responseFiles\wls-12.2.1\create_datasources.py
# Found 4/15 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.3\responseFiles\wls-12.2.1\setJTA.py
# Found 12/16 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# Found 3/17 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\baremetal\obmc\obmc_blockstorage.py
# Found 3/18 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\baremetal\obmc\obmc_images.py
# Found 3/19 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\baremetal\obmc\obmc_instances.py
# Found 0/20 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\baremetal\obmc\__init__.py
# Found 3/21 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\setup.py
# Found 3/22 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_add_agent.py
# Found 3/23 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_add_target.py
# Found 3/24 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_delete_agent.py
# Found 3/25 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_delete_target.py
# Found 3/26 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_full_deploy.py
# Found 3/27 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_get_agent_by_id.py
# Found 3/28 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_get_agent_by_name.py
# Found 3/29 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_get_agent_id.py
# Found 3/30 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_get_target_by_id.py
# Found 3/31 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_get_target_by_name.py
# Found 3/32 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_import_topology.py
# Found 3/33 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_initialize_topology.py
# Found 3/34 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_initial_deployment.py
# Found 3/35 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_is_primary_agent.py
# Found 3/36 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_is_primary_target.py
# Found 3/37 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_list_topologies.py
# Found 3/38 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_login.py
# Found 3/39 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_logout.py
# Found 3/40 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_session_confirmation.py
# Found 3/41 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_switch_agent_datasource.py
# Found 3/42 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_update_agent.py
# Found 3/43 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_update_target.py
# Found 0/44 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\__init__.py
# Found 5/45 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_add_agent.py
# Found 5/46 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_add_target.py
# Found 5/47 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_delete_agent.py
# Found 5/48 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_delete_target.py
# Found 1/49 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_exceptions.py
# Found 5/50 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_full_deploy.py
# Found 5/51 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_get_agent_by_id.py
# Found 5/52 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_get_agent_by_name.py
# Found 5/53 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_get_agent_id.py
# Found 5/54 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_get_target_by_id.py
# Found 6/55 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_get_target_by_name.py
# Found 5/56 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_import_topology.py
# Found 5/57 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_initialize_topology.py
# Found 5/58 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_initial_deployment.py
# Found 5/59 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_is_primary_agent.py
# Found 5/60 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_is_primary_target.py
# Found 5/61 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_list_topologies.py
# Found 4/62 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_logging.py
# Found 6/63 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_login.py
# Found 5/64 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_logout.py
# Found 6/65 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_session_confirmation.py
# Found 5/66 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_switch_agent_datasource.py
# Found 5/67 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_update_agent.py
# Found 5/68 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_update_target.py
# Found 9/69 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_utils.py
# Found 0/70 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\__init__.py
# Found 4/71 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\setup.py
# Found 1/72 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\instance_type_config.py
# Found 1/73 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\instance_type_config_webui.py
# Found 10/74 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# Found 10/75 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper_webui.py
# Found 0/76 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\__init__.py
# Found 9/77 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\commerce_setup_helper.py
# Found 5/78 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\load_user_metadata.py
# Found 1/79 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\setup_logger.py
# Found 0/80 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\__init__.py
# Found 4/81 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\create_atg_server_layers.py
# Found 0/82 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\__init__.py
# Found 3/83 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_1\atgpatch_helper.py
# Found 2/84 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_1\atgpatch_postinstall.py
# Found 3/85 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_1\atg_helper.py
# Found 0/86 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_1\__init__.py
# Found 3/87 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_2\atgpatch_helper.py
# Found 3/88 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_2\atg_helper.py
# Found 0/89 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_2\__init__.py
# Found 3/90 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_3\atgpatch_helper.py
# Found 3/91 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_3\atg_helper.py
# Found 0/92 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\atg\v11_3\__init__.py
# Found 1/93 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\database\oracle_schemas.py
# Found 0/94 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\database\__init__.py
# Found 4/95 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\database\v11g\oracle_rdbms_clone.py
# Found 5/96 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\database\v11g\oracle_rdbms_install.py
# Found 0/97 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\database\v11g\__init__.py
# Found 5/98 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\database\v12c\oracle_rdbms_install.py
# Found 0/99 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\database\v12c\__init__.py
# Found 0/100 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\__init__.py
# Found 4/101 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_1\cas_helper.py
# Found 4/102 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_1\mdex_helper.py
# Found 4/103 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_1\platform_helper.py
# Found 4/104 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_1\tools_helper.py
# Found 0/105 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_1\__init__.py
# Found 4/106 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_2\cas_helper.py
# Found 4/107 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_2\mdex_helper.py
# Found 4/108 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_2\platform_helper.py
# Found 4/109 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_2\tools_helper.py
# Found 0/110 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_2\__init__.py
# Found 4/111 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_3\cas_helper.py
# Found 4/112 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_3\mdex_helper.py
# Found 4/113 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_3\platform_helper.py
# Found 4/114 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_3\tools_helper.py
# Found 0/115 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\endeca\v11_3\__init__.py
# Found 4/116 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\java\java8_helper.py
# Found 5/117 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\java\java_generic.py
# Found 4/118 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\java\java_helper.py
# Found 0/119 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\java\__init__.py
# Found 0/120 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\otd\__init__.py
# Found 3/121 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\otd\v11_1\otd_config.py
# Found 5/122 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\otd\v11_1\otd_helper.py
# Found 0/123 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\otd\v11_1\__init__.py
# Found 2/124 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\sshkeys\copy_ssh_keys_helper.py
# Found 0/125 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\sshkeys\__init__.py
# Found 3/126 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\storage\advanced_storage_helper.py
# Found 3/127 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\storage\storage_helper.py
# Found 0/128 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\storage\__init__.py
# Found 4/129 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\weblogic_boot_properties.py
# Found 4/130 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\weblogic_create_managed_scripts.py
# Found 0/131 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\__init__.py
# Found 3/132 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_create_datasources.py
# Found 3/133 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_create_machine.py
# Found 3/134 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_create_managed_server.py
# Found 6/135 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_domain_config.py
# Found 3/136 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_domain_settings.py
# Found 5/137 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_helper.py
# Found 6/138 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_install_managed_server.py
# Found 5/139 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_packer.py
# Found 0/140 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\__init__.py
# Found 3/141 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\weblogic_create_datasources.py
# Found 3/142 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\weblogic_create_machine.py
# Found 3/143 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\weblogic_create_managed_server.py
# Found 6/144 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\weblogic_domain_config.py
# Found 3/145 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\weblogic_domain_settings.py
# Found 5/146 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\weblogic_helper.py
# Found 6/147 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\weblogic_install_managed_server.py
# Found 5/148 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\weblogic_packer.py
# Found 0/149 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_3\__init__.py
# Found 3/150 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\weblogic_create_datasources.py
# Found 3/151 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\weblogic_create_machine.py
# Found 3/152 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\weblogic_create_managed_server.py
# Found 6/153 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\weblogic_domain_config.py
# Found 3/154 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\weblogic_domain_settings.py
# Found 5/155 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\weblogic_helper.py
# Found 6/156 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\weblogic_install_managed_server.py
# Found 5/157 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\weblogic_packer.py
# Found 0/158 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_2_1\__init__.py
# Found 4/159 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\setup.py
# Found 13/160 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\add_orchestration.py
# Found 13/161 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\add_sshkey.py
# Found 12/162 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\authenticate.py
# Found 12/163 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\authenticate_oscs.py
# Found 5/164 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\connection.py
# Found 13/165 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_imagelist.py
# Found 13/166 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_imagelist_entry.py
# Found 13/167 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_instance_snapshot.py
# Found 13/168 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_ip_association.py
# Found 9/169 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_ip_network.py
# Found 9/170 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_ip_network_exchange.py
# Found 13/171 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_ip_reservation.py
# Found 13/172 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_launch_plan.py
# Found 13/173 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_machine_image.py
# Found 9/174 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_route.py
# Found 13/175 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_security_application.py
# Found 13/176 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_security_association.py
# Found 13/177 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_security_ip_list.py
# Found 13/178 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_security_list.py
# Found 13/179 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_security_rule.py
# Found 8/180 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_service.py
# Found 13/181 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_storage_attachment.py
# Found 13/182 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_storage_container.py
# Found 13/183 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_storage_volume.py
# Found 13/184 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_storage_volume_snapshot.py
# Found 9/185 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_vnicset.py
# Found 13/186 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_vpn_endpoint.py
# Found 13/187 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_imagelist.py
# Found 13/188 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_imagelist_entry.py
# Found 13/189 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_instance.py
# Found 13/190 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_instance_snapshot.py
# Found 13/191 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_ip_association.py
# Found 9/192 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_ip_network.py
# Found 9/193 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_ip_network_exchange.py
# Found 13/194 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_ip_reservation.py
# Found 13/195 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_machine_image.py
# Found 13/196 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_orchestration.py
# Found 9/197 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_route.py
# Found 13/198 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_security_application.py
# Found 13/199 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_security_association.py
# Found 13/200 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_security_ip_list.py
# Found 13/201 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_security_list.py
# Found 13/202 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_security_rule.py
# Found 9/203 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_service.py
# Found 13/204 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_sshkey.py
# Found 13/205 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_storage_attachment.py
# Found 13/206 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_storage_container.py
# Found 17/207 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_storage_object.py
# Found 13/208 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_storage_volume.py
# Found 13/209 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_storage_volume_snapshot.py
# Found 9/210 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_vnicset.py
# Found 13/211 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_vpn_endpoint.py
# Found 13/212 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_accounts.py
# Found 13/213 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_imagelists.py
# Found 13/214 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_imagelist_entries.py
# Found 13/215 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_instances.py
# Found 13/216 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_instance_snapshots.py
# Found 13/217 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_ip_associations.py
# Found 9/218 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_ip_networks.py
# Found 9/219 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_ip_network_exchanges.py
# Found 13/220 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_ip_reservations.py
# Found 13/221 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_machine_images.py
# Found 8/222 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_nodes_service.py
# Found 13/223 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_orchestrations.py
# Found 9/224 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_routes.py
# Found 13/225 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_security_applications.py
# Found 13/226 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_security_associations.py
# Found 13/227 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_security_ip_lists.py
# Found 13/228 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_security_lists.py
# Found 13/229 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_security_rules.py
# Found 8/230 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_service.py
# Found 8/231 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_services.py
# Found 13/232 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_shapes.py
# Found 13/233 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_sshkeys.py
# Found 13/234 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_storage_attachments.py
# Found 17/235 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_storage_objects.py
# Found 13/236 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_storage_properties.py
# Found 13/237 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_storage_volumes.py
# Found 13/238 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_storage_volume_snapshots.py
# Found 9/239 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_vnics.py
# Found 9/240 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_vnicsets.py
# Found 13/241 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\list_vpn_endpoints.py
# Found 14/242 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\occsutils.py
# Found 1/243 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\oc_exceptions.py
# Found 4/244 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\oc_logging.py
# Found 9/245 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\orchestration.py
# Found 6/246 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\oscsutils.py
# Found 13/247 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\start_orchestration.py
# Found 13/248 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\stop_orchestration.py
# Found 13/249 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_imagelist.py
# Found 9/250 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_ip_network.py
# Found 13/251 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_ip_reservation.py
# Found 13/252 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_orchestration.py
# Found 9/253 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_route.py
# Found 13/254 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_security_ip_list.py
# Found 13/255 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_security_list.py
# Found 13/256 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_security_rule.py
# Found 13/257 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_sshkey.py
# Found 13/258 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_storage_volume.py
# Found 9/259 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_vnicset.py
# Found 13/260 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\update_vpn_endpoint.py
# Found 20/261 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\upload_storage_object.py
# Found 0/262 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\__init__.py
# Found 12/263 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\openstack-metadata\load_openstack_userdata.py
# Found 7/264 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\manageprojects.py
# Found 8/265 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc.py
# Found 11/266 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_account.py
# Found 11/267 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_authenticate.py
# Found 14/268 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_imagelist.py
# Found 12/269 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_imagelistentry.py
# Found 12/270 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_instance.py
# Found 13/271 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_instancesnapshot.py
# Found 13/272 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_ipassociation.py
# Found 14/273 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_ipreservation.py
# Found 11/274 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_launchplan.py
# Found 12/275 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_machineimage.py
# Found 20/276 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_orchestration.py
# Found 13/277 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_security_application.py
# Found 13/278 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_security_association.py
# Found 14/279 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_security_iplist.py
# Found 14/280 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_security_list.py
# Found 14/281 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_security_rule.py
# Found 10/282 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_service.py
# Found 11/283 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_shape.py
# Found 14/284 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_sshkey.py
# Found 13/285 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_storageattachment.py
# Found 11/286 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_storageproperty.py
# Found 14/287 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_storagevolume.py
# Found 13/288 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_storagevolumesnapshot.py
# Found 13/289 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_storage_object.py
# Found 14/290 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_vpnendpoint.py
# Found 0/291 imports in C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\__init__.py
# Found 8/292 imports in C:\Users\eharris\devel\oracle\compute-cloud-service-demos\src\chef-server\oracle-ccs-deploy-chef.py
# Found 1/293 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\setup.py
# Found 4/294 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\aws_inventory\kubespray-aws-inventory.py
# Found 8/295 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\inventory_builder\inventory.py
# Found 2/296 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\inventory_builder\setup.py
# Found 5/297 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\inventory_builder\tests\test_inventory.py
# Found 7/298 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\terraform\terraform.py
# Found 1/299 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\library\kube.py
# Found 12/300 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\roles\bootstrap-os\files\get-pip.py
# Found 2/301 imports in C:\Users\eharris\devel\oracle\kubernetes-kubespray\roles\kubernetes-apps\kpm\library\kpm.py
# Found 4/302 imports in C:\Users\eharris\devel\oracle\oci-cli\setup.py
# Found 15/303 imports in C:\Users\eharris\devel\oracle\oci-cli\scripts\install\install.py
# Found 1/304 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\audit_cli_extended.py
# Found 0/305 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli.py
# Found 12/306 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_clients.py
# Found 0/307 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_constants.py
# Found 0/308 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_exceptions.py
# Found 8/309 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_root.py
# Found 14/310 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_setup.py
# Found 28/311 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_util.py
# Found 10/312 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\core_cli_extended.py
# Found 4/313 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\database_cli_extended.py
# Found 1/314 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\dns_cli_extended.py
# Found 1/315 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\email_cli_extended.py
# Found 0/316 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\filestorage_cli_extended.py
# Found 1/317 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\final_command_processor.py
# Found 2/318 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\formatting.py
# Found 4/319 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\identity_cli_extended.py
# Found 8/320 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\json_skeleton_utils.py
# Found 4/321 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\lb_cli_extended.py
# Found 12/322 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\objectstorage_cli_extended.py
# Found 3/323 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\retry_utils.py
# Found 1/324 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\string_utils.py
# Found 0/325 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\version.py
# Found 1/326 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\__init__.py
# Found 2/327 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\aliasing\command_group_with_alias.py
# Found 2/328 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\aliasing\parameter_alias.py
# Found 0/329 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\aliasing\__init__.py
# Found 1/330 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\custom_types\cli_case_insensitive_choice.py
# Found 1/331 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\custom_types\cli_complex_type.py
# Found 4/332 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\custom_types\cli_datetime.py
# Found 1/333 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\custom_types\cli_from_json.py
# Found 1/334 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\custom_types\object_storage_bulk_operation_output.py
# Found 0/335 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\custom_types\__init__.py
# Found 0/336 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\file_filters\file_filter_collection.py
# Found 2/337 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\file_filters\file_path_filter.py
# Found 0/338 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\file_filters\__init__.py
# Found 5/339 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\audit_cli.py
# Found 5/340 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\blockstorage_cli.py
# Found 5/341 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\compute_cli.py
# Found 5/342 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\database_cli.py
# Found 5/343 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\dns_cli.py
# Found 5/344 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\email_cli.py
# Found 5/345 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\filestorage_cli.py
# Found 5/346 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\identity_cli.py
# Found 5/347 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\loadbalancer_cli.py
# Found 5/348 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\objectstorage_cli.py
# Found 5/349 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\virtualnetwork_cli.py
# Found 0/350 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\generated\__init__.py
# Found 6/351 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\help_text_producer\help_text_producer.py
# Found 0/352 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\help_text_producer\__init__.py
# Found 1/353 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\delete_tasks.py
# Found 5/354 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\get_object_tasks.py
# Found 2/355 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\head_object_tasks.py
# Found 0/356 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\multipart_upload_tasks.py
# Found 1/357 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\pooled_multipart_object_assembler.py
# Found 2/358 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\transfer_manager.py
# Found 1/359 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\transfer_manager_config.py
# Found 2/360 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\upload_tasks.py
# Found 2/361 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\work_pool.py
# Found 0/362 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\work_pool_task.py
# Found 1/363 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\wrapped_semaphore.py
# Found 0/364 imports in C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\__init__.py
# Found 1/365 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\command_coverage_validator.py
# Found 15/366 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\conftest.py
# Found 2/367 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\tag_data_container.py
# Found 3/368 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_aliasing_commands_and_params.py
# Found 6/369 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_audit.py
# Found 3/370 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_blockstorage.py
# Found 5/371 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_canned_queries_in_cli_rc_file.py
# Found 13/372 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_cli_setup.py
# Found 7/373 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_compute.py
# Found 2/374 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_config_container.py
# Found 2/375 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_config_validation.py
# Found 6/376 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_database.py
# Found 10/377 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_default_files_command_invocation.py
# Found 4/378 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_default_values_from_file.py
# Found 4/379 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_dns.py
# Found 3/380 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_email.py
# Found 5/381 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_filestorage.py
# Found 3/382 imports in C:\Users\eharris\devel\oracle\oci-cli\tests\test_help.py
# ...
# Found 5/1122 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\tests\perf\manbench.py
# Found 7/1123 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\tests\perf\membench.py
# Found 6/1124 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\tests\ro_data\signing_certs\generate_certs.py
# Found 3/1125 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\tests\testsuite\testutils.py
# Found 5/1126 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\tests\testsuite\t_setup_teardown.py
# Found 0/1127 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\tests\testsuite\__init__.py
# Found 24/1128 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\apache2\depot\depot_index.py
# Found 13/1129 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\apache2\sysrepo\sysrepo_p5p.py
# Found 5/1130 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an2_ip.py
# Found 6/1131 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an2_ip_active.py
# Found 12/1132 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_catalog.py
# Found 11/1133 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_filelist.py
# Found 6/1134 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_first_timestamp.py
# Found 11/1135 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_ip_active.py
# Found 11/1136 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_manifest.py
# Found 12/1137 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_report.py
# Found 11/1138 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_search.py
# Found 2/1139 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\config.py
# Found 1/1140 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\in_footer.py
# Found 2/1141 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\in_header.py
# Found 7/1142 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\log.py
# Found 5/1143 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\translate.py
# Found 18/1144 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\publish\pkgdiff.py
# Found 26/1145 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\publish\pkgfmt.py
# Found 20/1146 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\publish\pkglint.py
# Found 28/1147 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\publish\pkgmerge.py
# Found 12/1148 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\publish\pkgmogrify.py
# Found 24/1149 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\publish\pkgsurf.py
# Found 10/1150 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\publish\update_file_layout.py
# Found 5/1151 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\qual-simulator\depot.py
# Found 7/1152 imports in C:\Users\eharris\devel\oracle\solaris-ips\src\util\qual-simulator\scenario.py
# Found 6/1153 imports in C:\Users\eharris\devel\oracle\solaris-openstack-utils\os_kilo_setup\os_keygen.py
# Found 19/1154 imports in C:\Users\eharris\devel\oracle\solaris-openstack-utils\os_kilo_setup\os_kilo_setup.py
# Found 30/1155 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\create.py
# Found 34/1156 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\deploy.py
# Found 35/1157 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\discover.py
# Found 21/1158 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\encrypt.py
# Found 20/1159 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\validate.py
# Found 0/1160 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\__init__.py
# Found 0/1161 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\__init__.py
# Found 40/1162 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\aliases.py
# Found 1/1163 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\alias_constants.py
# Found 43/1164 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\alias_entries.py
# Found 5/1165 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\alias_jvmargs.py
# Found 42/1166 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\alias_utils.py
# Found 0/1167 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\location_context.py
# Found 0/1168 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\model_constants.py
# Found 1/1169 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\validation_codes.py
# Found 1/1170 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\wlst_modes.py
# Found 0/1171 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\__init__.py
# Found 24/1172 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\exception\exception_helper.py
# Found 1/1173 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\exception\expection_types.py
# Found 0/1174 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\exception\__init__.py
# Found 12/1175 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\json\json_translator.py
# Found 0/1176 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\json\__init__.py
# Found 8/1177 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\logging\platform_logger.py
# Found 0/1178 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\logging\__init__.py
# Found 0/1179 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\__init__.py
# Found 18/1180 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\create\creator.py
# Found 79/1181 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\create\domain_creator.py
# Found 8/1182 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\create\domain_typedef.py
# Found 0/1183 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\create\__init__.py
# Found 31/1184 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\applications_deployer.py
# Found 15/1185 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\common_resources_deployer.py
# Found 6/1186 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\datasource_deployer.py
# Found 18/1187 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\deployer.py
# Found 15/1188 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\deployer_utils.py
# Found 27/1189 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\jms_resources_deployer.py
# Found 1/1190 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\log_helper.py
# Found 7/1191 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\model_deployer.py
# Found 14/1192 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\multi_tenant_resources_deployer.py
# Found 11/1193 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\resources_deployer.py
# Found 6/1194 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\wldf_resources_deployer.py
# Found 0/1195 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\deploy\__init__.py
# Found 16/1196 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\coherence_resources_discoverer.py
# Found 15/1197 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\common_resources_discoverer.py
# Found 13/1198 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\deployments_discoverer.py
# Found 16/1199 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\discoverer.py
# Found 10/1200 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\domain_info_discoverer.py
# Found 7/1201 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\global_resources_discoverer.py
# Found 7/1202 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\jms_resources_discoverer.py
# Found 11/1203 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\multi_tenant_discoverer.py
# Found 7/1204 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\multi_tenant_resources_discoverer.py
# Found 7/1205 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\multi_tenant_topology_discoverer.py
# Found 5/1206 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\resources_discoverer.py
# Found 15/1207 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\topology_discoverer.py
# Found 0/1208 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\discover\__init__.py
# Found 9/1209 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\encrypt\encryption_utils.py
# Found 0/1210 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\encrypt\__init__.py
# Found 2/1211 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\util\alias_helper.py
# Found 7/1212 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\util\archive_helper.py
# Found 59/1213 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\util\attribute_setter.py
# Found 6/1214 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\util\filter_helper.py
# Found 3/1215 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\util\wlst_helper.py
# Found 0/1216 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\util\__init__.py
# Found 9/1217 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\validate\usage_printer.py
# Found 8/1218 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\validate\validation_results.py
# Found 9/1219 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\validate\validation_utils.py
# Found 24/1220 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\validate\validator.py
# Found 0/1221 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\validate\__init__.py
# Found 11/1222 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\cla_utils.py
# Found 2/1223 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\dictionary_utils.py
# Found 1/1224 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\enum.py
# Found 1/1225 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\getcreds.py
# Found 4/1226 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\model.py
# Found 7/1227 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\model_context.py
# Found 10/1228 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\model_translator.py
# Found 4/1229 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\path_utils.py
# Found 1/1230 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\string_utils.py
# Found 10/1231 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\variables.py
# Found 7/1232 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\weblogic_helper.py
# Found 5/1233 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\wlst_helper.py
# Found 0/1234 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\__init__.py
# Found 11/1235 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\yaml\yaml_translator.py
# Found 0/1236 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\yaml\__init__.py
# Found 18/1237 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\aliases_test.py
# Found 40/1238 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\alias_json_file_test.py
# Found 3/1239 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\alias_jvmargs_test.py
# Found 2/1240 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\alias_utils_test.py
# Found 5/1241 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\attributes_test.py
# Found 3/1242 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\collections_test.py
# Found 11/1243 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\encryption_test.py
# Found 3/1244 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\exception_test.py
# Found 5/1245 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\logger_test.py
# Found 3/1246 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\translator_test.py
# Found 11/1247 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\validation_test.py
# Found 4/1248 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\variables_test.py
# Found 0/1249 imports in C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\__init__.py

# %%
print(f"Found {len(all_imported_libs)} files with imports")
# Out:
# Found 1249 files with imports

# %%
ils_in_py_file = all_imported_libs[WindowsPath(r'C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\add_orchestration.py')]

# %%
unique_libs = set()
ln_in_py_file = [il.library_name for il in ils_in_py_file]
for ln in ln_in_py_file:
    unique_libs.add(ln)
print(unique_libs)
# Out:
# {'json', 'logging', 'os', 'authenticate', 'datetime', 'locale', 'requests', 'getopt', 'occsutils', 'operator', 'sys'}

# %%
unique_libraries = set()
library_found_in: Dict[str, WindowsPath] = {}

for py_file, imported_libraries in all_imported_libs.items():
    lib_names_in_py_file = [il.library_name for il in imported_libraries]
    for lib_name in lib_names_in_py_file:
        if lib_name not in unique_libraries:
#             print(f"Adding {lib_name} ")
            unique_libraries.add(lib_name)
            library_found_in[lib_name] = [py_file]
        else:
            library_found_in[lib_name].append([py_file])

print(f"Found {len(unique_libraries)} in {len(all_imported_libs)}")
# Out:
# Found 222 in 1249

# %%
for lib_name in sorted(list(unique_libraries)):
    f = dict(lib_name=lib_name,  library_found_in=library_found_in)
    print("{:40} found in {:3} files: {}".format(lib_name, len(library_found_in[lib_name]),library_found_in[lib_name][0] ))
# Out:
# CONTENT_UPDATE_POLICY                    found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\actions\generic.py
# CREATING                                 found in   4 files: C:\Users\eharris\devel\oracle\oci-python-sdk\src\oci\identity\models\idp_group_mapping.py
# ConfigParser                             found in   7 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# GeoIP                                    found in   3 files: C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_ip_active.py
# M2Crypto                                 found in   1 files: C:\Users\eharris\devel\oracle\solaris-openstack-utils\os_kilo_setup\os_kilo_setup.py
# MySQLdb                                  found in   1 files: C:\Users\eharris\devel\oracle\solaris-openstack-utils\os_kilo_setup\os_kilo_setup.py
# OpenSSL                                  found in   4 files: C:\Users\eharris\devel\oracle\oci-python-sdk\src\oci\auth\federation_client.py
# StringIO                                 found in   2 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# __future__                               found in 150 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\terraform\terraform.py
# __init__                                 found in   6 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# __main__                                 found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\api\t_dependencies.py
# a                                        found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\options.py
# abc                                      found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\printengine.py
# an                                       found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\linkedimage\common.py
# an_report                                found in   7 files: C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an2_ip.py
# ansible                                  found in 102 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\baremetal\obmc\obmc_blockstorage.py
# argparse                                 found in  13 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc.py
# argumenttypes                            found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# array                                    found in   2 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\alias_utils.py
# arrow                                    found in   5 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_util.py
# ast                                      found in   4 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_utils.py
# atexit                                   found in   6 files: C:\Users\eharris\devel\oracle\solaris-ips\src\pkgrepo.py
# authenticate                             found in  68 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\add_orchestration.py
# authenticate_oscs                        found in   5 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_storage_container.py
# base64                                   found in   7 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\connection.py
# baseline                                 found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\pkg5unittest.py
# bcc_exceptions                           found in   4 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_utils.py
# bcc_logging                              found in   1 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_utils.py
# bcc_rest                                 found in  22 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_ansible\bcc_add_agent.py
# bcc_utils                                found in  45 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_add_agent.py
# bemgmt                                   found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\bootenv.py
# binascii                                 found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\misc.py
# boto3                                    found in   1 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\aws_inventory\kubespray-aws-inventory.py
# builtins                                 found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\utils.py
# bz2                                      found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\cpiofile.py
# cPickle                                  found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_report.py
# calendar                                 found in  11 files: C:\Users\eharris\devel\oracle\solaris-ips\src\client.py
# certgenerator                            found in   3 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\cli\t_depot_config.py
# cffi                                     found in   5 files: C:\Users\eharris\devel\oracle\solaris-ips\src\cffi_src\build_arch.py
# cherrypy                                 found in  16 files: C:\Users\eharris\devel\oracle\solaris-ips\src\depot.py
# click                                    found in  36 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\audit_cli_extended.py
# cliparser                                found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\opccli.py
# codecs                                   found in   4 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\config.py
# collections                              found in  55 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# colorama                                 found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\utils.py
# com                                      found in   1 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\wlst_helper.py
# common_util                              found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\internal\opc_cloud_storage_handler.py
# config                                   found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_report.py
# configparser                             found in   4 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\inventory_builder\inventory.py
# configure                                found in   2 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# connection                               found in   6 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\create_service.py
# contextlib                               found in   8 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_storage_object.py
# copy                                     found in  35 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# coverage                                 found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\pkg5unittest.py
# cryptography                             found in  50 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_setup.py
# ctypes                                   found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\portable\os_windows.py
# curses                                   found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\printengine.py
# customexecutor                           found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# datetime                                 found in 131 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# dateutil                                 found in   3 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_util.py
# decimal                                  found in   1 files: C:\Users\eharris\devel\oracle\solaris-openstack-utils\os_kilo_setup\os_keygen.py
# depot                                    found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\util\qual-simulator\scenario.py
# difflib                                  found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\pkg5unittest.py
# disk                                     found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\publisher.py
# distutils                                found in  26 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\setup.py
# email                                    found in   3 files: C:\Users\eharris\devel\oracle\oci-python-sdk\src\oci\signer.py
# encrypt                                  found in   1 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\test\python\encryption_test.py
# errno                                    found in  66 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# everything                               found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\linkedimage\__init__.py
# exceptions                               found in   7 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\manageprojects.py
# executor                                 found in   2 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# fcntl                                    found in   3 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\formatter.py
# filecmp                                  found in   3 files: C:\Users\eharris\devel\oracle\oci-cli\tests\test_object_storage.py
# fileinput                                found in  10 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\commerce_setup_helper.py
# fmri_set                                 found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\search_storage.py
# fnmatch                                  found in  12 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\file_filters\file_path_filter.py
# formatter                                found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\handlers.py
# functools                                found in  28 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\terraform\terraform.py
# getopt                                   found in 168 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\commerce_setup.py
# getpass                                  found in   7 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_utils.py
# gettext                                  found in  24 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# glob                                     found in   3 files: C:\Users\eharris\devel\oracle\oci-cli\scripts\install\install.py
# grp                                      found in   6 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\bundle\DirectoryBundle.py
# gzip                                     found in   3 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\cpiofile.py
# handlers                                 found in   2 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# hashlib                                  found in  29 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\delete_storage_object.py
# heapq                                    found in   2 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\get_object_tasks.py
# helpformatter                            found in   2 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# httpsig_cffi                             found in   2 files: C:\Users\eharris\devel\oracle\oci-python-sdk\src\oci\signer.py
# imp                                      found in   9 files: C:\Users\eharris\devel\oracle\solaris-ips\src\client.py
# importlib                                found in   7 files: C:\Users\eharris\devel\oracle\solaris-ips\src\client.py
# iniparse                                 found in   1 files: C:\Users\eharris\devel\oracle\solaris-openstack-utils\os_kilo_setup\os_kilo_setup.py
# inspect                                  found in   5 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\actions\__init__.py
# internal                                 found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\customexecutor.py
# inventory                                found in   1 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\inventory_builder\tests\test_inventory.py
# io                                       found in  20 files: C:\Users\eharris\devel\oracle\oci-cli\setup.py
# itertools                                found in  23 files: C:\Users\eharris\devel\oracle\solaris-ips\src\client.py
# java                                     found in 113 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\responseFiles\wls-12.1.2\createMachine.py
# javaos                                   found in  15 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\create.py
# javax                                    found in   1 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\tool\util\attribute_setter.py
# jmespath                                 found in   1 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_util.py
# json                                     found in 165 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# jsonrpclib                               found in   5 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\pipeutils.py
# jsonschema                               found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\client_api.py
# jwt                                      found in   1 files: C:\Users\eharris\devel\oracle\oci-python-sdk\src\oci\auth\security_token_container.py
# keyring                                  found in   3 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\configure.py
# kpm                                      found in   1 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\roles\kubernetes-apps\kpm\library\kpm.py
# libbe                                    found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\bootenv.py
# libbe_py                                 found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\bootenv.py
# list                                     found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\api.py
# locale                                   found in 115 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\add_orchestration.py
# logging                                  found in 216 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# logilab                                  found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\multiplatform.py
# macostools                               found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\portable\os_darwin.py
# mako                                     found in   6 files: C:\Users\eharris\devel\oracle\solaris-ips\src\depot-config.py
# math                                     found in   6 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_util.py
# md5                                      found in   6 files: C:\Users\eharris\devel\oracle\solaris-ips\src\util\log-scripts\an_catalog.py
# messages                                 found in  11 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# mmap                                     found in   2 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\internal\opc_cloud_storage_handler.py
# mock                                     found in   4 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\inventory_builder\tests\test_inventory.py
# modulefinder                             found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\flavor\depthlimitedmf.py
# multiprocessing                          found in   8 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\upload_storage_object.py
# oc                                       found in 220 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc_account.py
# oc_exceptions                            found in  14 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\occsutils.py
# oc_logging                               found in   1 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\occsutils.py
# oc_provision_config                      found in   2 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\manageprojects.py
# oc_provision_wrappers                    found in 140 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\commerce_setup.py
# occsutils                                found in 217 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\add_orchestration.py
# oci                                      found in 106 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_clients.py
# oci_cli                                  found in  32 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\objectstorage_cli_extended.py
# opaascli                                 found in   1 files: C:\Users\eharris\devel\oracle\psmcli\setup.py
# opcservice                               found in   4 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\configure.py
# operator                                 found in 106 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\add_orchestration.py
# optparse                                 found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\util\publish\pkglint.py
# or                                       found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\history.py
# oracle                                   found in 153 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\create.py
# oraclebmc                                found in   3 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\baremetal\obmc\obmc_blockstorage.py
# org                                      found in   3 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\alias_utils.py
# os                                       found in 512 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\commerce_setup.py
# os_keygen                                found in   1 files: C:\Users\eharris\devel\oracle\solaris-openstack-utils\os_kilo_setup\os_kilo_setup.py
# oscsutils                                found in  18 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\rest_wrappers\oc\oc\authenticate_oscs.py
# our                                      found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\linkedimage\common.py
# pip                                      found in   5 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\roles\bootstrap-os\files\get-pip.py
# pkg                                      found in 1186 files: C:\Users\eharris\devel\oracle\solaris-ips\src\client.py
# pkg5testenv                              found in   5 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\run.py
# pkg5unittest                             found in 106 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\pkg5testenv.py
# pkg_resources                            found in   4 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\webui\cgi\ansible_templates\library\oc.py
# pkg_test                                 found in   3 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\api\t_dependencies.py
# pkgdep_runpath                           found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\api\t_dependencies.py
# pkgutil                                  found in   1 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\roles\bootstrap-os\files\get-pip.py
# platform                                 found in  53 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\commerce_setup_helper.py
# ply                                      found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\query_parser.py
# posixpath                                found in   3 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# pprint                                   found in   9 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\commerce_setup.py
# prettytable                              found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\pkgrepo.py
# pty                                      found in   3 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\pkg5unittest.py
# pwd                                      found in   7 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\bundle\DirectoryBundle.py
# py_compile                               found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\setup.py
# pybonjour                                found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\transport\mdetect.py
# pycurl                                   found in   3 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\publisher.py
# pylint                                   found in   3 files: C:\Users\eharris\devel\oracle\solaris-ips\src\setup.py
# pytest                                   found in  28 files: C:\Users\eharris\devel\oracle\oci-cli\tests\conftest.py
# pythonUtils                              found in   1 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\utils.py
# pytz                                     found in   4 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_util.py
# random                                   found in  21 files: C:\Users\eharris\devel\oracle\oci-cli\tests\conftest.py
# re                                       found in  78 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# requests                                 found in 142 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_utils.py
# resource                                 found in   5 files: C:\Users\eharris\devel\oracle\oci-python-sdk\tests\util.py
# retrying                                 found in   5 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\objectstorage_cli_extended.py
# select                                   found in   4 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\pkgremote.py
# self                                     found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\pipeutils.py
# sets                                     found in   5 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\aliases\alias_jvmargs.py
# setuptools                               found in   9 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\setup.py
# shlex                                    found in   6 files: C:\Users\eharris\devel\oracle\compute-cloud-service-demos\src\chef-server\oracle-ccs-deploy-chef.py
# shutil                                   found in 113 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# signal                                   found in   9 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\help_text_producer\help_text_producer.py
# simplejson                               found in  32 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# six                                      found in 275 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_root.py
# socket                                   found in  17 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\weblogic_boot_properties.py
# solaris_install                          found in   1 files: C:\Users\eharris\devel\oracle\solaris-openstack-utils\os_kilo_setup\os_kilo_setup.py
# sphinx                                   found in   1 files: C:\Users\eharris\devel\oracle\oci-python-sdk\docs\conf.py
# sphinx_rtd_theme                         found in   1 files: C:\Users\eharris\devel\oracle\oci-python-sdk\docs\conf.py
# ssl                                      found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\depotcontroller.py
# stat                                     found in  49 files: C:\Users\eharris\devel\oracle\oci-cli\scripts\install\install.py
# stats                                    found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\util\qual-simulator\depot.py
# string                                   found in   5 files: C:\Users\eharris\devel\oracle\oci-cli\tests\test_default_files_command_invocation.py
# struct                                   found in   7 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\roles\bootstrap-os\files\get-pip.py
# subprocess                               found in  39 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# sys                                      found in 367 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\commerce_setup.py
# tarfile                                  found in   8 files: C:\Users\eharris\devel\oracle\oci-cli\scripts\install\install.py
# tempfile                                 found in  92 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# terminaltables                           found in   2 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_util.py
# termios                                  found in   2 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\formatter.py
# tests                                    found in   5 files: C:\Users\eharris\devel\oracle\oci-python-sdk\tests\conftest.py
# testutils                                found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\testsuite\t_setup_teardown.py
# textwrap                                 found in   7 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\cliparser.py
# the                                      found in  20 files: C:\Users\eharris\devel\oracle\oci-python-sdk\src\oci\dns\models\record.py
# threading                                found in  24 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\object_storage_transfer_manager\get_object_tasks.py
# time                                     found in  90 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\bcctools\bcc_rest\bcc_logging.py
# timeit                                   found in   3 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\perf\actionbench.py
# traceback                                found in  41 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\commerce_setup.py
# types                                    found in   8 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\catalog.py
# unittest                                 found in 118 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\contrib\inventory_builder\tests\test_inventory.py
# urllib                                   found in   3 files: C:\Users\eharris\devel\oracle\oci-cli\scripts\install\install.py
# urllib2                                  found in   5 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\baremetal-metadata\load_baremetal_userdata.py
# urlparse                                 found in   3 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\11.1\commerce_setup.py
# utils                                    found in  10 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\argumenttypes.py
# uuid                                     found in   6 files: C:\Users\eharris\devel\oracle\oci-cli\src\oci_cli\cli_util.py
# vcr                                      found in   2 files: C:\Users\eharris\devel\oracle\oci-cli\tests\test_config_container.py
# warnings                                 found in  17 files: C:\Users\eharris\devel\oracle\solaris-ips\src\client.py
# weakref                                  found in   2 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\version.py
# weblogic                                 found in   3 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\weblogic_helper.py
# weblogic_packer                          found in   3 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_wrappers\wls\v12_1_2\weblogic_domain_config.py
# wheel                                    found in   1 files: C:\Users\eharris\devel\oracle\kubernetes-kubespray\roles\bootstrap-os\files\get-pip.py
# which                                    found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\tests\api\t_pkglint.py
# win32api                                 found in   1 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\portable\os_windows.py
# wlsdeploy                                found in 686 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\create.py
# wlstModule                               found in   1 files: C:\Users\eharris\devel\oracle\weblogic-deploy-tooling\core\src\main\python\wlsdeploy\util\wlst_helper.py
# xml                                      found in  10 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\client\api_errors.py
# yaml                                     found in   5 files: C:\Users\eharris\devel\oracle\atg-commerce-iaas\common-python\oc_provisioning\oc_provision_config\orchestration_helper.py
# zipfile                                  found in   2 files: C:\Users\eharris\devel\oracle\psmcli\opaascli\opcservice.py
# zlib                                     found in  11 files: C:\Users\eharris\devel\oracle\solaris-ips\src\modules\cpiofile.py

# %%
'click' in unique_libraries
# Out:
# True
