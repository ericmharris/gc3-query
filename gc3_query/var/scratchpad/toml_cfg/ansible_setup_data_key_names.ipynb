# %%
import toml
import json
from pathlib import Path
from dataclasses import dataclass, make_dataclass, fields, asdict, replace
from pprint import pprint, pformat

from gc3_query.lib import *
from gc3_query.lib import BASE_DIR

# %%
ans_json_file = BASE_DIR.joinpath(r'opt\reference\ansible\setup_module_output.json').resolve()
print(f"ans_json_file={ans_json_file}, exists={ans_json_file.exists()}")
# Out:
# ans_json_file=C:\Users\eharris\devel\gc3-query\gc3_query\opt\reference\ansible\setup_module_output.json, exists=True

# %%
ans_data = json.load(ans_json_file.open())

# %%
pprint(ans_data)
# Out:
# {'ansible_facts': {'ansible_all_ipv4_addresses': ['192.168.1.107'],
#                    'ansible_all_ipv6_addresses': ['fe80::976:268b:1d85:a441'],
#                    'ansible_apparmor': {'status': 'enabled'},
#                    'ansible_architecture': 'x86_64',
#                    'ansible_bios_date': '04/16/2013',
#                    'ansible_bios_version': '2.04',
#                    'ansible_cmdline': {'BOOT_IMAGE': '/boot/vmlinuz-4.10.0-38-generic',
#                                        'quiet': True,
#                                        'ro': True,
#                                        'root': 'UUID=3b616a22-db98-425f-977c-4972918a2bd4',
#                                        'splash': True,
#                                        'vt.handoff': '7'},
#                    'ansible_date_time': {'date': '2018-06-02',
#                                          'day': '02',
#                                          'epoch': '1527966656',
# ...
